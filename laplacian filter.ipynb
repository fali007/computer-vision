# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread("image.jpg",0)
data=np.asarray(img)
plt.imshow(data)

# %%
data.shape
# Out:
# (340, 300)

# %%
high = [[  0  , 1 ,    0 ],
        [1 ,   -4  , 1 ],
        [  0  , 1 ,    0 ]]

# %%
new2=[]
for j in range(300-len(high)+1):
    temp=[]
    for k in range(340-len(high)+1):
        temp1=0
        for l in range(len(high)):
            for m in range(len(high)):
                temp1+=high[l][m]*data[k+l][j+m]
        temp.append(temp1)
    new2.append(temp)
new2=np.transpose(new)

# %%
plt.imshow(new)

# %%
# gaussian

# %%
fill = [[1 / 256, 4  / 256,  6 / 256,  4 / 256, 1 / 256],
        [4 / 256, 16 / 256, 24 / 256, 16 / 256, 4 / 256],
        [6 / 256, 24 / 256, 36 / 256, 24 / 256, 6 / 256],
        [4 / 256, 16 / 256, 24 / 256, 16 / 256, 4 / 256],
        [1 / 256, 4  / 256,  6 / 256,  4 / 256, 1 / 256]]

# %%
new=[]
for j in range(300-len(fill)+1):
    temp=[]
    for k in range(340-len(fill)+1):
        temp1=0
        for l in range(len(fill)):
            for m in range(len(fill)):
                temp1+=fill[l][m]*data[k+l][j+m]
        temp.append(temp1)
    new.append(temp)
new=np.transpose(new)
new=np.asarray(new)

# %%
plt.imshow(new)

# %%
# laplacian of gaussian
new.shape
# Out:
# (336, 296)

# %%
new1=[]
for j in range(296-len(high)+1):
    temp=[]
    for k in range(336-len(high)+1):
        temp1=0
        for l in range(len(high)):
            for m in range(len(high)):
                temp1+=high[l][m]*new[k+l][j+m]
        temp.append(temp1)
    new1.append(temp)
new1=np.transpose(new1)

# %%
plt.imshow(new1)

# %%
img=cv2.imread("image.jpg",0)

# %%
img=np.asarray(img)

# %%
img
# Out:
# array([[201, 199, 205, ..., 210, 205, 204],
#        [204, 198, 199, ..., 209, 203, 199],
#        [199, 194, 195, ..., 209, 204, 201],
#        ...,
#        [ 30,  29,  28, ...,  50,  51,  52],
#        [ 29,  28,  27, ...,  50,  51,  52],
#        [ 30,  28,  26, ...,  49,  51,  52]], dtype=uint8)

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (340, 300)
