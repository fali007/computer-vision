# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
data=cv2.imread("image.jpg",0)

# %%
plt.imshow(data)

# %%
data=ans

# %%
[height,width] = data.shape

# %%
size=5
ans=[]
for i in range(height-size+1):
    temp=[]
    for j in range(width-size+1):
        temp1=[]
        for k in range(size):
            for l in range(size):
                temp1.append(data[i+k][j+l])
        temp1=sorted(temp1)
        median=temp1[len(temp1)//2]
        if abs(data[i][j]-median)/data[i][j]<.7:
            temp.append(median)
        else:
            temp.append(data[i][j])
    ans.append(temp)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:12: RuntimeWarning: overflow encountered in ubyte_scalars
#   if sys.path[0] == '':
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:12: RuntimeWarning: divide by zero encountered in ubyte_scalars
#   if sys.path[0] == '':

# %%
ans=np.asarray(ans)
plt.imshow(ans)
